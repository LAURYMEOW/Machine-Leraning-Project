# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import statsmodels.api as sm
from scipy import stats

# %%
file_path = "../Resources.2/natural_disasters_final.csv"
temp_anom_df = pd.read_csv(file_path)
temp_anom_df.head()
# Out:
#         Entity  Year  Number of deaths from drought  \
# 0  Afghanistan  1971                              0
# 1  Afghanistan  1972                              0
# 2  Afghanistan  1976                              0
# 3  Afghanistan  1978                              0
# 4  Afghanistan  1980                              0
#
#    Number of deaths from extreme temperatures  Number of deaths from floods  \
# 0                                           0                             0
# 1                                           0                           150
# 2                                           0                            51
# 3                                           0                           120
# 4                                           0                             0
#
#    Number of deaths from storms  Number of deaths from wildfires  \
# 0                             0                                0
# ...

# %%
usa_disasters_df= temp_anom_df[(temp_anom_df['Entity'] == 'United States')]
usa_disasters_df.head()
# Out:
#              Entity  Year  Number of deaths from drought  \
# 4234  United States  1970                              0
# 4235  United States  1971                              0
# 4236  United States  1972                              0
# 4237  United States  1973                              0
# 4238  United States  1974                              0
#
#       Number of deaths from extreme temperatures  \
# 4234                                           0
# 4235                                           0
# 4236                                          10
# 4237                                          22
# 4238                                           0
#
#       Number of deaths from floods  Number of deaths from storms  \
# 4234                             0                            37
# 4235                             0                           158
# 4236                           237                           256
# ...

# %%
usa_disasters_df= usa_disasters_df.drop(['Entity'], axis=1)
usa_disasters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 4234 to 4284
# Data columns (total 25 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                51 non-null     int64
#  1   Number of deaths from drought                                       51 non-null     int64
#  2   Number of deaths from extreme temperatures                          51 non-null     int64
#  3   Number of deaths from floods                                        51 non-null     int64
#  4   Number of deaths from storms                                        51 non-null     int64
#  5   Number of deaths from wildfires                                     51 non-null     int64
#  6   Number of people affected by drought per 100,000                    51 non-null     float64
# ...

# %%
usa_disasters_df.set_index('Year',inplace = True)
usa_disasters_df.head()
# Out:
#       Number of deaths from drought  \
# Year
# 1970                              0
# 1971                              0
# 1972                              0
# 1973                              0
# 1974                              0
#
#       Number of deaths from extreme temperatures  \
# Year
# 1970                                           0
# 1971                                           0
# 1972                                          10
# 1973                                          22
# 1974                                           0
#
#       Number of deaths from floods  Number of deaths from storms  \
# Year
# 1970                             0                            37
# 1971                             0                           158
# 1972                           237                           256
# 1973                            56                            50
# 1974                             0                           352
#
# ...

# %%
axis = usa_disasters_df.plot.line(y='Total economic damages as a share of GDP',rot=0)
print(axis)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
axis = usa_disasters_df.plot.line(y='Number of deaths',rot=0)
print(axis)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
axis = usa_disasters_df.plot.line(y='Total economic damages',rot=0)
print(axis)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
usa_disasters_df.columns.tolist()
# Out:
# ['Number of deaths from drought',
#  'Number of deaths from extreme temperatures',
#  'Number of deaths from floods',
#  'Number of deaths from storms',
#  'Number of deaths from wildfires',
#  'Number of people affected by drought per 100,000',
#  'Number of people affected by extreme temperatures per 100,000',
#  'Number of people affected by floods per 100,000',
#  'Number of people affected by storms per 100,000',
#  'Number of people affected by wildfires per 100,000',
#  'Total economic damages from drought',
#  'Total economic damages from drought as a share of GDP',
#  'Total economic damages from extreme temperatures',
#  'Total economic damages from extreme temperatures as a share of GDP',
#  'Total economic damages from floods',
#  'Total economic damages from floods as a share of GDP',
#  'Total economic damages from storms',
#  'Total economic damages from storms as a share of GDP',
#  'Total economic damages from wildfires',
# ...

# %%
usa_disasters_df = usa_disasters_df.drop([
 'Number of deaths from drought',
 'Number of deaths from extreme temperatures',
 'Number of deaths from floods',
 'Number of deaths from storms',
 'Number of deaths from wildfires',
 'Number of people affected by drought per 100,000',
 'Number of people affected by extreme temperatures per 100,000',
 'Number of people affected by floods per 100,000',
 'Number of people affected by storms per 100,000',
 'Number of people affected by wildfires per 100,000',
 'Total economic damages from drought',
 'Total economic damages from drought as a share of GDP',
 'Total economic damages from extreme temperatures',
 'Total economic damages from extreme temperatures as a share of GDP',
 'Total economic damages from floods',
 'Total economic damages from floods as a share of GDP',
 'Total economic damages from storms',
 'Total economic damages from storms as a share of GDP',
 'Total economic damages from wildfires',
 'Total economic damages (000USD)'], axis=1)
usa_disasters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 2005 to 1988
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Total economic damages as a share of GDP  51 non-null     float64
#  1   Total economic damages                    51 non-null     int64
#  2   Number of people affected per 100,000     51 non-null     float64
#  3   Number of deaths                          51 non-null     int64
# dtypes: float64(2), int64(2)
# memory usage: 2.0 KB

# %%
usa_disasters_df= usa_disasters_df.sort_values('Total economic damages as a share of GDP',ascending=False)
usa_disasters_df.head(5)
# Out:
#       Total economic damages as a share of GDP  Total economic damages  \
# Year
# 2005                                  0.304835               159060330
# 2017                                  0.224262               190510000
# 2012                                  0.150755                98471000
# 1992                                  0.132279                34675000
# 2004                                  0.114073                55730270
#
#       Number of people affected per 100,000  Number of deaths
# Year
# 2005                             287.604170              1973
# 2017                             232.914167               336
# 2012                              29.107068               318
# 1992                              17.685444                97
# 2004                            1744.262920               219

# %%
usa_disasters_df= usa_disasters_df.sort_values('Total economic damages',ascending=False)
usa_disasters_df.head(5)
# Out:
#       Total economic damages as a share of GDP  Total economic damages  \
# Year
# 2017                                  0.224262               190510000
# 2005                                  0.304835               159060330
# 2012                                  0.150755                98471000
# 2020                                  0.078332                76600000
# 2018                                  0.051730                65350000
#
#       Number of people affected per 100,000  Number of deaths
# Year
# 2017                             232.914167               336
# 2005                             287.604170              1973
# 2012                              29.107068               318
# 2020                              12.356397               253
# 2018                             537.050591               269

# %%
usa_disasters_df= usa_disasters_df.sort_values('Number of deaths',ascending=False)
usa_disasters_df.head(5)
# Out:
#       Total economic damages as a share of GDP  Total economic damages  \
# Year
# 2005                                  0.304835               159060330
# 1980                                  0.028523                 3260000
# 1995                                  0.055270                16890000
# 2011                                  0.093372                59433000
# 1984                                  0.016164                 2610600
#
#       Number of people affected per 100,000  Number of deaths
# Year
# 2005                           2.876042e+02              1973
# 1980                           2.000048e+06              1308
# 1995                           7.516103e+01               879
# 2011                           1.269963e+02               809
# 1984                           5.876008e+00               545

# %%
usa_disasters_df= usa_disasters_df.sort_values('Year',ascending=True)
usa_disasters_df.head(5)
# Out:
#       Total economic damages as a share of GDP  Total economic damages  \
# Year
# 1970                                  0.013906                  697000
# 1971                                  0.000000                       0
# 1972                                  0.043390                 2220000
# 1973                                  0.009647                  550000
# 1974                                  0.016179                 1000000
#
#       Number of people affected per 100,000  Number of deaths
# Year
# 1970                               0.000000                37
# 1971                               0.000000               158
# 1972                               1.406668               503
# 1973                               0.114323               128
# 1974                               0.000000               352

# %%
usa_disasters_df.describe()
# Out:
#        Total economic damages as a share of GDP  Total economic damages  \
# count                                 51.000000            5.100000e+01
# mean                                   0.042254            2.225079e+07
# std                                    0.056954            3.833230e+07
# min                                    0.000000            0.000000e+00
# 25%                                    0.011539            1.995450e+06
# 50%                                    0.024874            7.245000e+06
# 75%                                    0.042922            1.859320e+07
# max                                    0.304835            1.905100e+08
#
#        Number of people affected per 100,000  Number of deaths
# count                           5.100000e+01         51.000000
# mean                            3.078682e+05        322.725490
# std                             8.584848e+05        324.539309
# min                             0.000000e+00         27.000000
# ...

# %% [markdown]
# 1. Total economic damages as a share of GDP Analysis

# %%
# Extract feature we're interested in
data_1 = usa_disasters_df['Total economic damages as a share of GDP']

# Generate histogram/distribution plot
sb.displot(data_1, stat="density")

plt.show()

# %%
sb.displot(data_1, discrete = True, kde = True)
plt.show()

# %%
# Histogram
# ==============================================================================
# Valores de la media (mu) y desviación típica (sigma) de los datos
mu, sigma = stats.norm.fit(data_1)

# Valores teóricos de la normal en el rango observado
x_hat = np.linspace(min(data_1), max(data_1), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(x_hat, y_hat, linewidth=2, label='normal')
ax.hist(x=data_1, density=True, bins=30, color="#3182bd", alpha=0.5)
ax.plot(data_1, np.full_like(data_1, -0.01), '|k', markeredgewidth=1)
ax.set_title('USA Economic Damage as a shareof GDP Distribution')
ax.set_xlabel('USA Economic Damage as a shareof GDP')
ax.set_ylabel('Probability Density')
ax.legend();

# %%
print('Kursotis:', stats.kurtosis(data_1))
print('Skewness:', stats.skew(data_1))
# Out:
# Kursotis: 8.886530387673837
# Skewness: 2.8361766664855086

# %%
# Shapiro-Wilk test
# ==============================================================================
shapiro_test = stats.shapiro(data_1)
shapiro_test
# Out:
# ShapiroResult(statistic=0.6555816531181335, pvalue=1.1200366190067257e-09)

# %%
# D'Agostino's K-squared test
# ==============================================================================
k2, p_value = stats.normaltest(data_1)
print(f"Estadístico = {k2}, p-value = {p_value}")
# Out:
# Estadístico = 52.68014163808513, p-value = 3.6362404223435867e-12

# %% [markdown]
# 2. Total Economic Damages Analysis

# %%
# Extract feature we're interested in
data_2 = usa_disasters_df['Total economic damages']

# Generate histogram/distribution plot
sb.displot(data_2, stat="density")

plt.show()

# %%
# Histogram
# ==============================================================================
# Valores de la media (mu) y desviación típica (sigma) de los datos
mu, sigma = stats.norm.fit(data_2)

# Valores teóricos de la normal en el rango observado
x_hat = np.linspace(min(data_2), max(data_2), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(x_hat, y_hat, linewidth=2, label='normal')
ax.hist(x=data_2, density=True, bins=30, color="#3182bd", alpha=0.5)
ax.plot(data_2, np.full_like(data_2, -0.01), '|k', markeredgewidth=1)
ax.set_title('USA Total Economic Damages Distribution')
ax.set_xlabel('USA Total Economic Damage')
ax.set_ylabel('Probability Density')
ax.legend();

# %%
print('Kursotis:', stats.kurtosis(data_2))
print('Skewness:', stats.skew(data_2))
# Out:
# Kursotis: 8.406559891575682
# Skewness: 2.8456434208692056

# %%
# Shapiro-Wilk test
# ==============================================================================
shapiro_test = stats.shapiro(data_2)
shapiro_test
# Out:
# ShapiroResult(statistic=0.6001207232475281, pvalue=1.5060802605049162e-10)

# %%
# D'Agostino's K-squared test
# ==============================================================================
k2, p_value = stats.normaltest(data_2)
print(f"Estadístico = {k2}, p-value = {p_value}")
# Out:
# Estadístico = 52.104065174281814, p-value = 4.850047645849539e-12

# %% [markdown]
# 3. Number of deaths Analysis

# %%
# Extract feature we're interested in
data_3 = usa_disasters_df['Number of deaths']

# Generate histogram/distribution plot
sb.displot(data_3, stat="density")

plt.show()

# %%
# Histogram
# ==============================================================================
# Valores de la media (mu) y desviación típica (sigma) de los datos
mu, sigma = stats.norm.fit(data_3)

# Valores teóricos de la normal en el rango observado
x_hat = np.linspace(min(data_3), max(data_3), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(x_hat, y_hat, linewidth=2, label='normal')
ax.hist(x=data_3, density=True, bins=30, color="#3182bd", alpha=0.5)
ax.plot(data_3, np.full_like(data_3, -0.01), '|k', markeredgewidth=1)
ax.set_title('USA Number of deaths')
ax.set_xlabel('USA Number of deaths')
ax.set_ylabel('Probability Density')
ax.legend();

# %%
print('Kursotis:', stats.kurtosis(data_3))
print('Skewness:', stats.skew(data_3))
# Out:
# Kursotis: 12.735499886697845
# Skewness: 3.3033276352245076

# %%
# Shapiro-Wilk test
# ==============================================================================
shapiro_test = stats.shapiro(data_3)
shapiro_test
# Out:
# ShapiroResult(statistic=0.6378816962242126, pvalue=5.775139810815233e-10)

# %%
# D'Agostino's K-squared test
# ==============================================================================
k2, p_value = stats.normaltest(data_3)
print(f"Estadístico = {k2}, p-value = {p_value}")
# Out:
# Estadístico = 62.88522666346708, p-value = 2.2112942336046728e-14
